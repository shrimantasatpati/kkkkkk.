# %%
import pandas as pd
df =pd.read_excel(r"C:\Users\shrimantas\Downloads\20230411124015_CELONIS_EXPORT.xlsx")
#m=(df1.Variants.unique())
m = list((df['Variants'].unique()))
print(type(m))
# Out:
# <class 'list'>

# %% [markdown]
# #
#
#
# df = df.assign(Variants=df.Variants.str.split(",")).explode('Variants')
#
#
#
# variants = list(df['Variants'].unique())

# %%
import pandas as pd

def new_col(csv, variants):
    df =pd.read_excel(csv)
    for variant in variants:
    
        df[variant]=df.apply(lambda row:  1 if variant in row['Variants'] else 0, axis=1)
    return df

# %%
csv=r"C:\Users\shrimantas\Downloads\20230411124015_CELONIS_EXPORT.xlsx"
variants=['Create Purchase Order Item',
 ' Record Goods Receipt',
 'Requisition Creation ARIBA',
 ' Requisition Submission ARIBA',
 ' GIS Procurement Ops',
 ' GIS COD Approval',
 ' BFM Approver',
 ' CPO Hierarchy Level 1',
 ' Create Purchase Order Item',
 ' Record Invoice Receipt',
 ' Remove Payment Block',
 ' Clear Invoice',
 ' Record Service Entry Sheet',
 ' FSS Approval',
 ' Requisition Creation ARIBA',
 ' CPO Hierarchy Level 2',
 ' CPO Hierarchy Level 3',
 ' Delete Purchase Order Item',
 ' Level 1 CostCenter Based Approvers',
 ' Level 2 CostCenter Based Approvers',
 ' FMG CPO Buyer Approval',
 ' Cancel Goods Receipt',
 ' BSS Approval node',
 ' BSS BFM Approver',
 ' BSS and Civil CPO approval',
 ' BSS CPO Level2 Approver',
 ' Requester_Watcher',
 ' FPO CPO',
 ' FSS PO Team',
 ' GIS CPO Hierarchy Level 2',
 ' IMG Fulfillment Team',
 ' CPO Buyer Group for Non Catalog',
 ' IBU Procurement Ops',
 ' BFM Approver for ESP and IAS',
 ' Wividus Group for Punchout/Catalog',
 ' Change Schedule Line Date',
 ' Begin Quality Inspection',
 ' Finish Quality Inspection',
 ' Quality: Accepted',
 'Create Purchase Requisition Item',
 ' BFM Approver 920&800',
 ' IBU CPO Hierarchy Level 2',
 ' IAS/ESP DH',
 ' Change Quantity',
 ' Block Purchase Order Item',
 ' ESL BFM',
 ' Change Price',
 ' Level 1 Project Approvers',
 ' Level 2 Project Approvers',
 ' Receive Order Confirmation',
 ' Change Storage Location',
 ' IAS Contract Requisition',
 ' CPO Hierarchy Level 4',
 ' Refuse Purchase Order',
 ' Receive advanced shipment notice (ASN)',
 ' Level 3 CostCenter Based Approvers',
 ' Cancel Invoice Receipt',
 ' Level-3 Project Approvers',
 ' Release Purchase Requisition',
 ' Create Purchase Requisition Item',
 ' IOPS',
 ' IT Fulfillment Team',
 ' CTO User',
 ' Set Payment Block',
 ' Change Approval for Purchase Order',
 ' Level 4 CostCenter Based Approvers',
 ' Reactivate Purchase Order Item',
 ' Change Delivery Indicator',
 ' Update Order Confirmation',
 ' Change Outward Delivery Indicator',
 'Refuse Purchase Order',
 ' CPO Watcher',
 ' Change Final Invoice Indicator',
 ' Change Currency',
 ' Send Purchase Order']

# %%
new_col(csv,variants)
# Out:
#                                                 Variants  Case count  \
# 0       Create Purchase Order Item, Record Goods Receipt       60393
# 1      Requisition Creation ARIBA, Requisition Submis...        7275
# 2      Requisition Creation ARIBA, Requisition Submis...        6475
# 3      Create Purchase Order Item, Record Goods Recei...        4769
# 4      Requisition Creation ARIBA, Requisition Submis...        4620
# ...                                                  ...         ...
# 17256  Requisition Creation ARIBA, Requisition Submis...           1
# 17257  Requisition Creation ARIBA, Requisition Submis...           1
# 17258  Requisition Creation ARIBA, Requisition Submis...           1
# 17259  Requisition Creation ARIBA, Requisition Submis...           1
# 17260  Requisition Creation ARIBA, Requisition Submis...           1
#
#        Create Purchase Order Item   Record Goods Receipt  \
# 0                               1                      1
# ...
